# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6
# Ans:
# values:'hello',-87.8,6
# Operators:*,-,/,+

# %% [raw]
# 2. What is the difference between string and variable?
# Ans:Variable is the name of the location in the memory of the computer.Whereas string is the type of the values which is written inside the quotes and assigned to the variable.

# %% [raw]
# 3. Describe three different data types.
# The different types of data types in python is :
# 1.Numeric
# 2.Set
# 3.Boolean
# 4.sequence [Tuple,List,Strings]
# 5.Dictionary

# %%
4. What is an expression made up of? What do all expressions do?
An Expression is the combination of operators and operands that is interpreted to produce 
some other value.An expression is an instruction that combines the values and evaaluates it inot a single value.

# %%
5. This assignment statements, like spam = 10. What is the difference between an
expression and a statement?
Ans:Expressions contain identifiers,literals and operators.Statement on the other hand ,are everything that can make up a line 
    (or several lines) of python code.Expressions are statements as well.

# %%
6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1
Ans:22

# %%
7. What should the values of the following two terms be?
'spam'+'spamspam'
'spam'*3
Ans:'spamspamspam'
    'spamspamspam'

# %%
8. Why is eggs a valid variable name while 100 is invalid?
Ans:Variable name should ne only made of alphabets and underscore.

# %%
9. What three functions can be used to get the integer, floating-point number, or string
version of a value?
ANs:int(),float(),str()

# %%
10. Why does this expression cause an error? How can you fix it?
'I have eaten ' + 99 + ' burritos'
Ans: Integer to string concatination is not allowed.
